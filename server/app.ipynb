# %%
from typing import TypedDict, Annotated, Optional
from langgraph.graph import add_messages, StateGraph, END
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.checkpoint.memory import MemorySaver
from uuid import uuid4
import json

load_dotenv()
# Out:
# True

# %%
import os
from dotenv import load_dotenv

load_dotenv()

llm = ChatGroq(  model="meta-llama/llama-4-scout-17b-16e-instruct", temperature=0.5)

# %%
search_tool = TavilySearchResults(max_results=4)

tools = [search_tool]

memory = MemorySaver()

# %%
llm_with_tools = llm.bind_tools(tools=tools)

# %%
from langchain_core.messages import AIMessage, HumanMessage, ToolMessage

class State(TypedDict):
    messages: Annotated[list, add_messages]

async def model(state: State):
    result = await llm_with_tools.ainvoke(state["messages"])
    return {
        "messages": [result], 
    }

async def tools_router(state: State):
    last_message = state["messages"][-1]

    if(hasattr(last_message, "tool_calls") and len(last_message.tool_calls) > 0):
        return "tool_node"
    else: 
        return END
    
async def tool_node(state):
    """Custom tool node that handles tool calls from the LLM."""
    # Get the tool calls from the last message
    tool_calls = state["messages"][-1].tool_calls
    
    # Initialize list to store tool messages
    tool_messages = []
    
    # Process each tool call
    for tool_call in tool_calls:
        tool_name = tool_call["name"]
        tool_args = tool_call["args"]
        tool_id = tool_call["id"]
        
        # Handle the search tool
        if tool_name == "tavily_search_results_json":
            # Execute the search tool with the provided arguments
            search_results = await search_tool.ainvoke(tool_args)
            
            # Create a ToolMessage for this result
            tool_message = ToolMessage(
                content=str(search_results),
                tool_call_id=tool_id,
                name=tool_name
            )
            
            tool_messages.append(tool_message)
    
    # Add the tool messages to the state
    return {"messages": tool_messages}

graph_builder = StateGraph(State)

graph_builder.add_node("model", model)
graph_builder.add_node("tool_node", tool_node)
graph_builder.set_entry_point("model")

graph_builder.add_conditional_edges("model", tools_router)
graph_builder.add_edge("tool_node", "model")

graph = graph_builder.compile(checkpointer=memory)

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

display(
    Image(
        graph.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API
        )
    )
)

# %%
config = {
    "configurable": {
        "thread_id": 456789
    }
}

response = await graph.ainvoke({
    "messages": [HumanMessage(content="When is the next spaceX launch?")], 
}, config=config)

response
# Out:
# {'messages': [HumanMessage(content='When is the next spaceX launch?', additional_kwargs={}, response_metadata={}, id='d8b05c1e-3470-4f8a-a804-e962dce21a92'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'ch9c2158x', 'function': {'arguments': '{"query":"next SpaceX launch"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 713, 'total_tokens': 743, 'completion_time': 0.06822936, 'prompt_time': 0.02169476, 'queue_time': 0.05362815, 'total_time': 0.08992412}, 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_5d3e4e58e1', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--b8070dd9-e6b2-418b-9bc3-06b8b54b1a6f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch'}, 'id': 'ch9c2158x', 'type': 'tool_call'}], usage_metadata={'input_tokens': 713, 'output_tokens': 30, 'total_tokens': 743}),
#   ToolMessage(content="[{'title': 'Next Spaceflight | Rocket Launch Schedule', 'url': 'https://nextspaceflight.com/', 'content': 'Next Spaceflight | Rocket Launch Schedule\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Nusantara Lima\\n\\n ASOG \\n\\nWed Sep 10, 2025 00:01 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetailsWatch\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Tranche 1 Transport Layer B\\n\\n OCISLY \\n\\nWed Sep 10, 2025 14:12 UTC\\n\\nSLC-4E, Vandenberg SFB, California, USA', 'score': 0.79080546}, {'title': 'Upcoming Launches - NASASpaceFlight.com -', 'url': 'https://www.nasaspaceflight.com/schedule/', 'content': '### Glonass-K1 n°18LNEXT\\n\\nSoyuz 2.1b/Fregat-M | Space Forces of the Russian Federation \\nSat, Sep 13, 2025, 02:30 AM UTC\\n\\n   ### Starlink Group 17-10\\n\\nFalcon 9 Block 5 | SpaceX \\nSat, Sep 13, 2025, 03:41 PM UTC\\n\\n   ### CRS NG-23\\n\\nFalcon 9 Block 5 | SpaceX \\nSun, Sep 14, 2025, 10:11 PM UTC\\n\\n   ### Unknown Payload\\n\\nLong March 2C/YZ-1S | China Aerospace Science and Technology Corporation \\nMon, Sep 15, 2025, 01:20 AM UTC\\n\\n   ### Starlink Group 17-12 [...] Upcoming Launches - NASASpaceFlight.com\\n\\nPOPULAR ### NASA, SpaceX launch Crew-11 mission to the ISS\\n\\nJuly 31, 2025  Featured ### Joint NASA-ISRO NISAR satellite launches from India\\n\\nJuly 30, 2025  European ### How Pangea is reshaping rocket propulsion by reigniting...\\n\\nJuly 29, 2025  Chinese ### Launch Roundup: SpaceX to launch Crew-11 to ISS;...\\n\\nJuly 28, 2025   Chinese ### Launch Roundup: SpaceX to launch Crew-11 to ISS;...', 'score': 0.7644879}, {'title': 'SpaceX Launch Schedule - RocketLaunch.org', 'url': 'https://rocketlaunch.org/launch-schedule/spacex', 'content': 'Sponsorship PackagesSpace JobsSupport Our Mission\\n\\n[](\\n\\nLaunch Schedules\\n\\nUpcoming Launches\\n\\nPast Launches\\n\\nSpaceX Launches\\n\\nStarship Next Launches\\n\\nFalcon 9 Next Launches\\n\\nFalcon Heavy Next Launches\\n\\nNASA Launches\\n\\nSLS Launches\\n\\nBoca Chica Launches\\n\\nCape Canaveral Launches\\n\\nKennedy Space Center Launches\\n\\nVandenberg SFB Launches\\n\\nLaunch Sites\\n\\nLaunch Sites Map\\n\\nStarbase\\n\\nCape Canaveral\\n\\nKennedy Space Center\\n\\nVandenberg SFB\\n\\nGuiana Space Centre\\n\\nBaikonur Cosmodrome\\n\\nLocation\\n\\nUnited States [...] TBD\\n\\nOct 2025\\n\\n📍 Vandenberg SFB\\n\\n🚀 Falcon 9 Block 5\\n\\n🎯 Sun-Synchronous Orbit\\n\\nDedicated rideshare flight to a sun-synchronous orbit with dozens of small microsatellites and nanosatellites for commercial and government customers.\\n\\nLast Update: Changed launch site.\\n\\nSentinel-6B\\n\\nImage 23: SpaceX logo\\nSpaceX\\n\\nTBD\\n\\nNov 2025\\n\\n📍 Vandenberg SFB\\n\\n🚀 Falcon 9 Block 5\\n\\n🎯 Low Earth Orbit [...] Upcoming SpaceX Launches\\n\\nSDA Tranche 1 Transport Layer B\\n\\nImage 12: SpaceX logo\\nSpaceX\\n\\nT-1 days\\n\\n10 Sep, 2:12pm\\n\\nUTC\\n\\n📍 Vandenberg SFB\\n\\n🚀 Falcon 9 Block 5\\n\\n🎯 Polar Orbit', 'score': 0.7507177}, {'title': 'List of Falcon 9 and Falcon Heavy launches - Wikipedia', 'url': 'https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches', 'content': '| After first six Crew Dragon launches of NASA USCV award, a further three missions for SpaceX were announced on December 3, 2021. These launches carry up to four astronauts and 100 kg (220 lb) of cargo to the ISS as well as feature a lifeboat function to evacuate astronauts from ISS in case of an emergency. SpaceX flew its 50th astronaut on this Crew Dragon launch.( | [...] | Launch of 20 Starlink v2 mini satellites to a 525 km (326 mi) orbit at an inclination of 53° to expand internet constellation and two SpaceX Starshield satellites as rideshare.( |\\n| 312 | March 21, 2024 20:55( | F9 B5 B1080‑6 | Cape Canaveral, SLC‑40 | SpaceX CRS-30 (Dragon C ...
#   AIMessage(content="The next SpaceX launch is scheduled for September 10, 2025, at 00:01 UTC, with the Nusantara Lima mission on a Falcon9 Block5 rocket from SLC-40, Cape Canaveral SFS, Florida, USA. Additionally, there are several other upcoming launches, including:\n\n* September 10, 2025, 14:12 UTC: Tranche1 Transport Layer B on a Falcon9 Block5 rocket from SLC-4E, Vandenberg SFB, California, USA\n* September 13, 2025, 03:41 PM UTC: Starlink Group17-10 on a Falcon9 Block5 rocket\n* September 14, 2025, 10:11 PM UTC: CRS NG-23 on a Falcon9 Block5 rocket\n\nPlease note that launch schedules are subject to change, and it's always best to check with reliable sources for the latest information.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 189, 'prompt_tokens': 2077, 'total_tokens': 2266, 'completion_time': 0.428695971, 'prompt_time': 0.072772351, 'queue_time': 0.048324438, 'total_time': 0.501468322}, 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--a6260f33-1368-44cd-9387-348f312df138-0', usage_metadata={'input_tokens': 2077, 'output_tokens': 189, 'total_tokens': 2266})]}

# %%
config = {
    "configurable": {
        "thread_id": 8
    }
}

# Use async for to iterate over the async generator
async for event in graph.astream_events({
    "messages": [HumanMessage(content="When is the next spacex launch?")],
}, config=config, version="v2"):
    print(event)
# Out:
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={})]}}, 'name': 'LangGraph', 'tags': [], 'run_id': '97148894-65ec-438e-ac64-9fd6b01bca5d', 'metadata': {'thread_id': 8}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='840164c6-dd31-4658-bc78-c39c8b2c0fc4')]}}, 'name': 'model', 'tags': ['graph:step:1'], 'run_id': '125126f8-38a5-4a46-a9dc-74fdaf778fc3', 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f4ac0ab1-bbb3-a550-f925-52ce60d8f374'}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d']}
# {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='840164c6-dd31-4658-bc78-c39c8b2c0fc4')]]}}, 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'run_id': 'd953bdd1-0d5f-4015-ba83-62c62d1be192', 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f4ac0ab1-bbb3-a550-f925-52ce60d8f374', 'checkpoint_ns': 'model:f4ac0ab1-bbb3-a550-f925-52ce60d8f374', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '125126f8-38a5-4a46-a9dc-74fdaf778fc3']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--d953bdd1-0d5f-4015-ba83-62c62d1be192')}, 'run_id': 'd953bdd1-0d5f-4015-ba83-62c62d1be192', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f4ac0ab1-bbb3-a550-f925-52ce60d8f374', 'checkpoint_ns': 'model:f4ac0ab1-bbb3-a550-f925-52ce60d8f374', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '125126f8-38a5-4a46-a9dc-74fdaf778fc3']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'zwxje04dn', 'function': {'arguments': '{"query":"Next SpaceX launch"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={}, id='run--d953bdd1-0d5f-4015-ba83-62c62d1be192', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Next SpaceX launch'}, 'id': 'zwxje04dn', 'type': 'tool_call'}], tool_call_chunks=[{'name': 'tavily_search_results_json', 'args': '{"query":"Next SpaceX launch"}', 'id': 'zwxje04dn', 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'd953bdd1-0d5f-4015-ba83-62c62d1be192', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f4ac0ab1-bbb3-a550-f925-52ce60d8f374', 'checkpoint_ns': 'model:f4ac0ab1-bbb3-a550-f925-52ce60d8f374', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '125126f8-38a5-4a46-a9dc-74fdaf778fc3']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand'}, id='run--d953bdd1-0d5f-4015-ba83-62c62d1be192', usage_metadata={'input_tokens': 713, 'output_tokens': 30, 'total_tokens': 743})}, 'run_id': 'd953bdd1-0d5f-4015-ba83-62c62d1be192', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f4ac0ab1-bbb3-a550-f925-52ce60d8f374', 'checkpoint_ns': 'model:f4ac0ab1-bbb3-a550-f925-52ce60d8f374', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '125126f8-38a5-4a46-a9dc-74fdaf778fc3']}
# {'event': 'on_chat_model_end', 'data': {'output': AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'zwxje04dn', 'function': {'arguments': '{"query":"Next SpaceX launch"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand'}, id='run--d953bdd1-0d5f-4015-ba83-62c62d1be192', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Next SpaceX launch'}, 'id': 'zwxje04dn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 713, 'output_tokens': 30, 'total_tokens': 743}), 'input': {'messages': [[HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='840164c6-dd31-4658-bc78-c39c8b2c0fc4')]]}}, 'run_id': 'd953bdd1-0d5f-4015-ba83-62c62d1be192', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f4ac0ab1-bbb3-a550-f925-52ce60d8f374', 'checkpoint_ns': 'model:f4ac0ab1-bbb3-a550-f925-52ce60d8f374', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '125126f8-38a5-4a46-a9dc-74fdaf778fc3']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='840164c6-dd31-4658-bc78-c39c8b2c0fc4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'zwxje04dn', 'function': {'arguments': '{"query":"Next SpaceX launch"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand'}, id='run--d953bdd1-0d5f-4015-ba83-62c62d1be192', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Next SpaceX launch'}, 'id': 'zwxje04dn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 713, 'output_tokens': 30, 'total_tokens': 743})]}}, 'name': 'tools_router', 'tags': ['seq:step:3'], 'run_id': 'fbac81a1-b6dd-4617-8be0-f824fefd8818', 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f4ac0ab1-bbb3-a550-f925-52ce60d8f374'}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '125126f8-38a5-4a46-a9dc-74fdaf778fc3']}
# {'event': 'on_chain_end', 'data': {'output': 'tool_node', 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='840164c6-dd31-4658-bc78-c39c8b2c0fc4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'zwxje04dn', 'function': {'arguments': '{"query":"Next SpaceX launch"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand'}, id='run--d953bdd1-0d5f-4015-ba83-62c62d1be192', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Next SpaceX launch'}, 'id': 'zwxje04dn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 713, 'output_tokens': 30, 'total_tokens': 743})]}}, 'run_id': 'fbac81a1-b6dd-4617-8be0-f824fefd8818', 'name': 'tools_router', 'tags': ['seq:step:3'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f4ac0ab1-bbb3-a550-f925-52ce60d8f374'}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '125126f8-38a5-4a46-a9dc-74fdaf778fc3']}
# {'event': 'on_chain_stream', 'run_id': '125126f8-38a5-4a46-a9dc-74fdaf778fc3', 'name': 'model', 'tags': ['graph:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f4ac0ab1-bbb3-a550-f925-52ce60d8f374'}, 'data': {'chunk': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'zwxje04dn', 'function': {'arguments': '{"query":"Next SpaceX launch"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand'}, id='run--d953bdd1-0d5f-4015-ba83-62c62d1be192', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Next SpaceX launch'}, 'id': 'zwxje04dn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 713, 'output_tokens': 30, 'total_tokens': 743})]}}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'zwxje04dn', 'function': {'arguments': '{"query":"Next SpaceX launch"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand'}, id='run--d953bdd1-0d5f-4015-ba83-62c62d1be192', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Next SpaceX launch'}, 'id': 'zwxje04dn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 713, 'output_tokens': 30, 'total_tokens': 743})]}, 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='840164c6-dd31-4658-bc78-c39c8b2c0fc4')]}}, 'run_id': '125126f8-38a5-4a46-a9dc-74fdaf778fc3', 'name': 'model', 'tags': ['graph:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f4ac0ab1-bbb3-a550-f925-52ce60d8f374'}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d']}
# {'event': 'on_chain_stream', 'run_id': '97148894-65ec-438e-ac64-9fd6b01bca5d', 'name': 'LangGraph', 'tags': [], 'metadata': {'thread_id': 8}, 'data': {'chunk': {'model': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'zwxje04dn', 'function': {'arguments': '{"query":"Next SpaceX launch"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand'}, id='run--d953bdd1-0d5f-4015-ba83-62c62d1be192', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Next SpaceX launch'}, 'id': 'zwxje04dn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 713, 'output_tokens': 30, 'total_tokens': 743})]}}}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='840164c6-dd31-4658-bc78-c39c8b2c0fc4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'zwxje04dn', 'function': {'arguments': '{"query":"Next SpaceX launch"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand'}, id='run--d953bdd1-0d5f-4015-ba83-62c62d1be192', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Next SpaceX launch'}, 'id': 'zwxje04dn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 713, 'output_tokens': 30, 'total_tokens': 743})]}}, 'name': 'tool_node', 'tags': ['graph:step:2'], 'run_id': '3ac20e55-eabe-43f4-bf21-820ced1bd0f4', 'metadata': {'thread_id': 8, 'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:df5b613f-7994-9efe-307b-a7782cb4d92c'}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d']}
# {'event': 'on_tool_start', 'data': {'input': {'query': 'Next SpaceX launch'}}, 'name': 'tavily_search_results_json', 'tags': ['seq:step:1'], 'run_id': 'c7398670-49cf-4cac-8ddc-558c32b7787f', 'metadata': {'thread_id': 8, 'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:df5b613f-7994-9efe-307b-a7782cb4d92c', 'checkpoint_ns': 'tool_node:df5b613f-7994-9efe-307b-a7782cb4d92c'}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '3ac20e55-eabe-43f4-bf21-820ced1bd0f4']}
# {'event': 'on_tool_end', 'data': {'output': [{'title': 'Upcoming Missions - SpaceXNow', 'url': 'https://spacexnow.com/upcoming', 'content': '# Upcoming Missions\n\nClick a mission title to watch its live webcast. Titles will be underlined when a webcast is available.  \nNote: You must log in to view webcasts on X/Twitter.\n\nStarlink Group 17-12\n\nBy SpaceX\n\nF9 B5 - B1088.10   \n VSFB, SLC-4E   \n\n9/17/2025, 11:41:00 AM EDT\n\n  \n\nLaunching in 1 day, 3 hours, 35 minutes\n\nStarlink Group 10-61\n\nBy SpaceX\n\nF9 B5 - B1092.7   \n CCSFS, SLC-40   \n\n9/18/2025, 5:30:00 AM EDT\n\n Reused\n\n  \n\nLaunching in 1 day, 21 hours, 24 minutes\n\nStarlink Group 10-27 [...] F9 B5   \n LC-39A or SLC-40\n\n GTO\n ASDS\n\n  \n\nNET Q4 2025\n\nStarship Flight 11\n\nBy SpaceX\n\nStarship - B15.2   \n Starbase\n\n TBD\n Ocean\n Reused\n\n  \n\nNET Q4 2025\n\nUSSF-31\n\nBy USSF\n\nF9 B5   \n LC-39A or SLC-40\n\n TBD\n\n  \n\nNET 2025\n\nNROL-77\n\nBy NRO\n\nF9 B5   \n LC-39A or SLC-40\n\n TBD\n\n  \n\nNET 2025\n\nT1TL-A\n\nBy SDA\n\nF9 B5   \n VSFB, SLC-4E\n\n Polar\n OCISLY\n\n  \n\nNET Q4 2025\n\nSPAINSAT NG II\n\nBy Hisdesat\n\nF9 B5   \n CCSFS, SLC-40   \n\nNET Oct 22, 2025, EDT\n\n GTO\n Expended\n\n  \n\nLaunching in 1 month, 6 days, 3 hours [...] Starship Propellant Transfer Chaser\n\nBy SpaceX\n\nStarship   \n Starbase\n\n LEO\n\n  \n\nNET 2026\n\nTransporter 16\n\nBy Multiple\n\nF9 B5   \n VSFB, SLC-4E   \n\nNET Feb 01, 2026, EST\n\n SSO\n\n  \n\nLaunching in 4 months, 17 days, 23 hours\n\nT1TR-C\n\nBy SDA\n\nF9 B5   \n VSFB, SLC-4E\n\n Polar\n\n  \n\nNET Q1 2026\n\nUSCV-12 (Crew-12)\n\nBy NASA\n\nF9 B5   \n KSC, LC-39A\n\n LEO\n LZ-2\n\n  \n\nNET Q1 2026\n\nT1TL-F\n\nBy SDA\n\nF9 B5   \n VSFB, SLC-4E\n\n Polar\n OCISLY\n\n  \n\nNET Q1 2026\n\nEchoStar XXV\n\nBy EchoStar\n\nTBD   \n LC-39A or SLC-40\n\n GTO', 'score': 0.7882741}, {'title': 'Next Spaceflight | Rocket Launch Schedule', 'url': 'https://nextspaceflight.com/', 'content': 'Next Spaceflight | Rocket Launch Schedule\n\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\n\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\n\n SpaceX \n\n##### Falcon 9 Block 5 | Nusantara Lima\n\n ASOG \n\nWed Sep 10, 2025 00:01 UTC\n\nSLC-40, Cape Canaveral SFS, Florida, USA \n\nDetailsWatch\n\n SpaceX \n\n##### Falcon 9 Block 5 | Tranche 1 Transport Layer B\n\n OCISLY \n\nWed Sep 10, 2025 14:12 UTC\n\nSLC-4E, Vandenberg SFB, California, USA', 'score': 0.7539928}, {'title': 'SpaceX Launch Schedule - RocketLaunch.org', 'url': 'https://rocketlaunch.org/launch-schedule/spacex', 'content': 'TBD\n\nOct 2025\n\n📍 Vandenberg SFB\n\n🚀 Falcon 9 Block 5\n\n🎯 Sun-Synchronous Orbit\n\nDedicated rideshare flight to a sun-synchronous orbit with dozens of small microsatellites and nanosatellites for commercial and government customers.\n\nLast Update: Changed launch site.\n\nSentinel-6B\n\nImage 23: SpaceX logo\nSpaceX\n\nTBD\n\nNov 2025\n\n📍 Vandenberg SFB\n\n🚀 Falcon 9 Block 5\n\n🎯 Low Earth Orbit [...] Sponsorship PackagesSpace JobsSupport Our Mission\n\n[](\n\nLaunch Schedules\n\nUpcoming Launches\n\nPast Launches\n\nSpaceX Launches\n\nStarship Next Launches\n\nFalcon 9 Next Launches\n\nFalcon Heavy Next Launches\n\nNASA Launches\n\nSLS Launches\n\nBoca Chica Launches\n\nCape Canaveral Launches\n\nKennedy Space Center Launches\n\nVandenberg SFB Launches\n\nLaunch Sites\n\nLaunch Sites Map\n\nStarbase\n\nCape Canaveral\n\nKennedy Space Center\n\nVandenberg SFB\n\nGuiana Space Centre\n\nBaikonur Cosmodrome\n\nLocation\n\nUnited States', 'score': 0.7463059}, {'title': 'List of Falcon 9 and Falcon Heavy launches - Wikipedia', 'url': 'https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches', 'content': '| Launch of 20 Starlink v2 mini satellites to a 525 km (326 mi) orbit at an inclination of 53° to expand internet constellation and two SpaceX Starshield satellites as rideshare.( |\n| 312 | March 21, 2024 20:55( | F9 B5  ...
# {'event': 'on_chain_stream', 'run_id': '3ac20e55-eabe-43f4-bf21-820ced1bd0f4', 'name': 'tool_node', 'tags': ['graph:step:2'], 'metadata': {'thread_id': 8, 'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:df5b613f-7994-9efe-307b-a7782cb4d92c'}, 'data': {'chunk': {'messages': [ToolMessage(content="[{'title': 'Upcoming Missions - SpaceXNow', 'url': 'https://spacexnow.com/upcoming', 'content': '# Upcoming Missions\\n\\nClick a mission title to watch its live webcast. Titles will be underlined when a webcast is available.  \\nNote: You must log in to view webcasts on X/Twitter.\\n\\nStarlink Group 17-12\\n\\nBy SpaceX\\n\\nF9 B5 - B1088.10   \\n VSFB, SLC-4E   \\n\\n9/17/2025, 11:41:00 AM EDT\\n\\n  \\n\\nLaunching in 1 day, 3 hours, 35 minutes\\n\\nStarlink Group 10-61\\n\\nBy SpaceX\\n\\nF9 B5 - B1092.7   \\n CCSFS, SLC-40   \\n\\n9/18/2025, 5:30:00 AM EDT\\n\\n Reused\\n\\n  \\n\\nLaunching in 1 day, 21 hours, 24 minutes\\n\\nStarlink Group 10-27 [...] F9 B5   \\n LC-39A or SLC-40\\n\\n GTO\\n ASDS\\n\\n  \\n\\nNET Q4 2025\\n\\nStarship Flight 11\\n\\nBy SpaceX\\n\\nStarship - B15.2   \\n Starbase\\n\\n TBD\\n Ocean\\n Reused\\n\\n  \\n\\nNET Q4 2025\\n\\nUSSF-31\\n\\nBy USSF\\n\\nF9 B5   \\n LC-39A or SLC-40\\n\\n TBD\\n\\n  \\n\\nNET 2025\\n\\nNROL-77\\n\\nBy NRO\\n\\nF9 B5   \\n LC-39A or SLC-40\\n\\n TBD\\n\\n  \\n\\nNET 2025\\n\\nT1TL-A\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n OCISLY\\n\\n  \\n\\nNET Q4 2025\\n\\nSPAINSAT NG II\\n\\nBy Hisdesat\\n\\nF9 B5   \\n CCSFS, SLC-40   \\n\\nNET Oct 22, 2025, EDT\\n\\n GTO\\n Expended\\n\\n  \\n\\nLaunching in 1 month, 6 days, 3 hours [...] Starship Propellant Transfer Chaser\\n\\nBy SpaceX\\n\\nStarship   \\n Starbase\\n\\n LEO\\n\\n  \\n\\nNET 2026\\n\\nTransporter 16\\n\\nBy Multiple\\n\\nF9 B5   \\n VSFB, SLC-4E   \\n\\nNET Feb 01, 2026, EST\\n\\n SSO\\n\\n  \\n\\nLaunching in 4 months, 17 days, 23 hours\\n\\nT1TR-C\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n\\n  \\n\\nNET Q1 2026\\n\\nUSCV-12 (Crew-12)\\n\\nBy NASA\\n\\nF9 B5   \\n KSC, LC-39A\\n\\n LEO\\n LZ-2\\n\\n  \\n\\nNET Q1 2026\\n\\nT1TL-F\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n OCISLY\\n\\n  \\n\\nNET Q1 2026\\n\\nEchoStar XXV\\n\\nBy EchoStar\\n\\nTBD   \\n LC-39A or SLC-40\\n\\n GTO', 'score': 0.7882741}, {'title': 'Next Spaceflight | Rocket Launch Schedule', 'url': 'https://nextspaceflight.com/', 'content': 'Next Spaceflight | Rocket Launch Schedule\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Nusantara Lima\\n\\n ASOG \\n\\nWed Sep 10, 2025 00:01 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetailsWatch\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Tranche 1 Transport Layer B\\n\\n OCISLY \\n\\nWed Sep 10, 2025 14:12 UTC\\n\\nSLC-4E, Vandenberg SFB, California, USA', 'score': 0.7539928}, {'title': 'SpaceX Launch Schedule - RocketLaunch.org', 'url': 'https://rocketlaunch.org/launch-schedule/spacex', 'content': 'TBD\\n\\nOct 2025\\n\\n📍 Vandenberg SFB\\n\\n🚀 Falcon 9 Block 5\\n\\n🎯 Sun-Synchronous Orbit\\n\\nDedicated rideshare flight to a sun-synchronous orbit with dozens of small microsatellites and nanosatellites for commercial and government customers.\\n\\nLast Update: Changed launch site.\\n\\nSentinel-6B\\n\\nImage 23: SpaceX logo\\nSpaceX\\n\\nTBD\\n\\nNov 2025\\n\\n📍 Vandenberg SFB\\n\\n🚀 Falcon 9 Block 5\\n\\n🎯 Low Earth Orbit [...] Sponsorship PackagesSpace JobsSupport Our Mission\\n\\n[](\\n\\nLaunch Schedules\\n\\nUpcoming Launches\\n\\nPast Launches\\n\\nSpaceX Launches\\n\\nStarship Next Launches\\n\\nFalcon 9 Next Launches\\n\\nFalcon Heavy Next Launches\\n\\nNASA Launches\\n\\nSLS Launches\\n\\nBoca Chica Launches\\n\\nCape Canaveral La ...
# {'event': 'on_chain_end', 'data': {'output': {'messages': [ToolMessage(content="[{'title': 'Upcoming Missions - SpaceXNow', 'url': 'https://spacexnow.com/upcoming', 'content': '# Upcoming Missions\\n\\nClick a mission title to watch its live webcast. Titles will be underlined when a webcast is available.  \\nNote: You must log in to view webcasts on X/Twitter.\\n\\nStarlink Group 17-12\\n\\nBy SpaceX\\n\\nF9 B5 - B1088.10   \\n VSFB, SLC-4E   \\n\\n9/17/2025, 11:41:00 AM EDT\\n\\n  \\n\\nLaunching in 1 day, 3 hours, 35 minutes\\n\\nStarlink Group 10-61\\n\\nBy SpaceX\\n\\nF9 B5 - B1092.7   \\n CCSFS, SLC-40   \\n\\n9/18/2025, 5:30:00 AM EDT\\n\\n Reused\\n\\n  \\n\\nLaunching in 1 day, 21 hours, 24 minutes\\n\\nStarlink Group 10-27 [...] F9 B5   \\n LC-39A or SLC-40\\n\\n GTO\\n ASDS\\n\\n  \\n\\nNET Q4 2025\\n\\nStarship Flight 11\\n\\nBy SpaceX\\n\\nStarship - B15.2   \\n Starbase\\n\\n TBD\\n Ocean\\n Reused\\n\\n  \\n\\nNET Q4 2025\\n\\nUSSF-31\\n\\nBy USSF\\n\\nF9 B5   \\n LC-39A or SLC-40\\n\\n TBD\\n\\n  \\n\\nNET 2025\\n\\nNROL-77\\n\\nBy NRO\\n\\nF9 B5   \\n LC-39A or SLC-40\\n\\n TBD\\n\\n  \\n\\nNET 2025\\n\\nT1TL-A\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n OCISLY\\n\\n  \\n\\nNET Q4 2025\\n\\nSPAINSAT NG II\\n\\nBy Hisdesat\\n\\nF9 B5   \\n CCSFS, SLC-40   \\n\\nNET Oct 22, 2025, EDT\\n\\n GTO\\n Expended\\n\\n  \\n\\nLaunching in 1 month, 6 days, 3 hours [...] Starship Propellant Transfer Chaser\\n\\nBy SpaceX\\n\\nStarship   \\n Starbase\\n\\n LEO\\n\\n  \\n\\nNET 2026\\n\\nTransporter 16\\n\\nBy Multiple\\n\\nF9 B5   \\n VSFB, SLC-4E   \\n\\nNET Feb 01, 2026, EST\\n\\n SSO\\n\\n  \\n\\nLaunching in 4 months, 17 days, 23 hours\\n\\nT1TR-C\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n\\n  \\n\\nNET Q1 2026\\n\\nUSCV-12 (Crew-12)\\n\\nBy NASA\\n\\nF9 B5   \\n KSC, LC-39A\\n\\n LEO\\n LZ-2\\n\\n  \\n\\nNET Q1 2026\\n\\nT1TL-F\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n OCISLY\\n\\n  \\n\\nNET Q1 2026\\n\\nEchoStar XXV\\n\\nBy EchoStar\\n\\nTBD   \\n LC-39A or SLC-40\\n\\n GTO', 'score': 0.7882741}, {'title': 'Next Spaceflight | Rocket Launch Schedule', 'url': 'https://nextspaceflight.com/', 'content': 'Next Spaceflight | Rocket Launch Schedule\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Nusantara Lima\\n\\n ASOG \\n\\nWed Sep 10, 2025 00:01 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetailsWatch\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Tranche 1 Transport Layer B\\n\\n OCISLY \\n\\nWed Sep 10, 2025 14:12 UTC\\n\\nSLC-4E, Vandenberg SFB, California, USA', 'score': 0.7539928}, {'title': 'SpaceX Launch Schedule - RocketLaunch.org', 'url': 'https://rocketlaunch.org/launch-schedule/spacex', 'content': 'TBD\\n\\nOct 2025\\n\\n📍 Vandenberg SFB\\n\\n🚀 Falcon 9 Block 5\\n\\n🎯 Sun-Synchronous Orbit\\n\\nDedicated rideshare flight to a sun-synchronous orbit with dozens of small microsatellites and nanosatellites for commercial and government customers.\\n\\nLast Update: Changed launch site.\\n\\nSentinel-6B\\n\\nImage 23: SpaceX logo\\nSpaceX\\n\\nTBD\\n\\nNov 2025\\n\\n📍 Vandenberg SFB\\n\\n🚀 Falcon 9 Block 5\\n\\n🎯 Low Earth Orbit [...] Sponsorship PackagesSpace JobsSupport Our Mission\\n\\n[](\\n\\nLaunch Schedules\\n\\nUpcoming Launches\\n\\nPast Launches\\n\\nSpaceX Launches\\n\\nStarship Next Launches\\n\\nFalcon 9 Next Launches\\n\\nFalcon Heavy Next Launches\\n\\nNASA Launches\\n\\nSLS Launches\\n\\nBoca Chica Launches\\n\\nCape Canaveral Launches\\n\\nKennedy Space Center Launches\\n\\nVandenberg SFB Launches\\n\\nLaunch Sites\\n\\nLaunch Sites Map\\n\\nStarbase\\n\\nCape Canaveral\\n\\nKennedy Space Center\\n\\nVandenberg SFB\\n\\nGuiana Space Centre\\n\\nBaikonur Cosmodrome\\n\\nLocation\\n\\nUnited States', 'score': 0.7463059}, {'title': 'List of Falcon 9 and Falcon Heavy launches - Wik ...
# {'event': 'on_chain_stream', 'run_id': '97148894-65ec-438e-ac64-9fd6b01bca5d', 'name': 'LangGraph', 'tags': [], 'metadata': {'thread_id': 8}, 'data': {'chunk': {'tool_node': {'messages': [ToolMessage(content="[{'title': 'Upcoming Missions - SpaceXNow', 'url': 'https://spacexnow.com/upcoming', 'content': '# Upcoming Missions\\n\\nClick a mission title to watch its live webcast. Titles will be underlined when a webcast is available.  \\nNote: You must log in to view webcasts on X/Twitter.\\n\\nStarlink Group 17-12\\n\\nBy SpaceX\\n\\nF9 B5 - B1088.10   \\n VSFB, SLC-4E   \\n\\n9/17/2025, 11:41:00 AM EDT\\n\\n  \\n\\nLaunching in 1 day, 3 hours, 35 minutes\\n\\nStarlink Group 10-61\\n\\nBy SpaceX\\n\\nF9 B5 - B1092.7   \\n CCSFS, SLC-40   \\n\\n9/18/2025, 5:30:00 AM EDT\\n\\n Reused\\n\\n  \\n\\nLaunching in 1 day, 21 hours, 24 minutes\\n\\nStarlink Group 10-27 [...] F9 B5   \\n LC-39A or SLC-40\\n\\n GTO\\n ASDS\\n\\n  \\n\\nNET Q4 2025\\n\\nStarship Flight 11\\n\\nBy SpaceX\\n\\nStarship - B15.2   \\n Starbase\\n\\n TBD\\n Ocean\\n Reused\\n\\n  \\n\\nNET Q4 2025\\n\\nUSSF-31\\n\\nBy USSF\\n\\nF9 B5   \\n LC-39A or SLC-40\\n\\n TBD\\n\\n  \\n\\nNET 2025\\n\\nNROL-77\\n\\nBy NRO\\n\\nF9 B5   \\n LC-39A or SLC-40\\n\\n TBD\\n\\n  \\n\\nNET 2025\\n\\nT1TL-A\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n OCISLY\\n\\n  \\n\\nNET Q4 2025\\n\\nSPAINSAT NG II\\n\\nBy Hisdesat\\n\\nF9 B5   \\n CCSFS, SLC-40   \\n\\nNET Oct 22, 2025, EDT\\n\\n GTO\\n Expended\\n\\n  \\n\\nLaunching in 1 month, 6 days, 3 hours [...] Starship Propellant Transfer Chaser\\n\\nBy SpaceX\\n\\nStarship   \\n Starbase\\n\\n LEO\\n\\n  \\n\\nNET 2026\\n\\nTransporter 16\\n\\nBy Multiple\\n\\nF9 B5   \\n VSFB, SLC-4E   \\n\\nNET Feb 01, 2026, EST\\n\\n SSO\\n\\n  \\n\\nLaunching in 4 months, 17 days, 23 hours\\n\\nT1TR-C\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n\\n  \\n\\nNET Q1 2026\\n\\nUSCV-12 (Crew-12)\\n\\nBy NASA\\n\\nF9 B5   \\n KSC, LC-39A\\n\\n LEO\\n LZ-2\\n\\n  \\n\\nNET Q1 2026\\n\\nT1TL-F\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n OCISLY\\n\\n  \\n\\nNET Q1 2026\\n\\nEchoStar XXV\\n\\nBy EchoStar\\n\\nTBD   \\n LC-39A or SLC-40\\n\\n GTO', 'score': 0.7882741}, {'title': 'Next Spaceflight | Rocket Launch Schedule', 'url': 'https://nextspaceflight.com/', 'content': 'Next Spaceflight | Rocket Launch Schedule\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Nusantara Lima\\n\\n ASOG \\n\\nWed Sep 10, 2025 00:01 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetailsWatch\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Tranche 1 Transport Layer B\\n\\n OCISLY \\n\\nWed Sep 10, 2025 14:12 UTC\\n\\nSLC-4E, Vandenberg SFB, California, USA', 'score': 0.7539928}, {'title': 'SpaceX Launch Schedule - RocketLaunch.org', 'url': 'https://rocketlaunch.org/launch-schedule/spacex', 'content': 'TBD\\n\\nOct 2025\\n\\n📍 Vandenberg SFB\\n\\n🚀 Falcon 9 Block 5\\n\\n🎯 Sun-Synchronous Orbit\\n\\nDedicated rideshare flight to a sun-synchronous orbit with dozens of small microsatellites and nanosatellites for commercial and government customers.\\n\\nLast Update: Changed launch site.\\n\\nSentinel-6B\\n\\nImage 23: SpaceX logo\\nSpaceX\\n\\nTBD\\n\\nNov 2025\\n\\n📍 Vandenberg SFB\\n\\n🚀 Falcon 9 Block 5\\n\\n🎯 Low Earth Orbit [...] Sponsorship PackagesSpace JobsSupport Our Mission\\n\\n[](\\n\\nLaunch Schedules\\n\\nUpcoming Launches\\n\\nPast Launches\\n\\nSpaceX Launches\\n\\nStarship Next Launches\\n\\nFalcon 9 Next Launches\\n\\nFalcon Heavy Next Launches\\n\\nNASA Launches\\n\\nSLS Launches\\n\\nBoca Chica Launches\\n\\nCape Canaveral Launches\\n\\nKennedy Space Center Launches\\n\\nVandenberg SFB Launches\\n\\nLaunch Sites\\n\\nLaunch Sites Map\\n\\nStarbase\\n\\nCape Canaveral\\n\\nKennedy Space Center\\n\\nVandenberg SFB\\n\\nGuiana Space Centre\\n\\nBaikon ...
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='840164c6-dd31-4658-bc78-c39c8b2c0fc4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'zwxje04dn', 'function': {'arguments': '{"query":"Next SpaceX launch"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand'}, id='run--d953bdd1-0d5f-4015-ba83-62c62d1be192', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Next SpaceX launch'}, 'id': 'zwxje04dn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 713, 'output_tokens': 30, 'total_tokens': 743}), ToolMessage(content="[{'title': 'Upcoming Missions - SpaceXNow', 'url': 'https://spacexnow.com/upcoming', 'content': '# Upcoming Missions\\n\\nClick a mission title to watch its live webcast. Titles will be underlined when a webcast is available.  \\nNote: You must log in to view webcasts on X/Twitter.\\n\\nStarlink Group 17-12\\n\\nBy SpaceX\\n\\nF9 B5 - B1088.10   \\n VSFB, SLC-4E   \\n\\n9/17/2025, 11:41:00 AM EDT\\n\\n  \\n\\nLaunching in 1 day, 3 hours, 35 minutes\\n\\nStarlink Group 10-61\\n\\nBy SpaceX\\n\\nF9 B5 - B1092.7   \\n CCSFS, SLC-40   \\n\\n9/18/2025, 5:30:00 AM EDT\\n\\n Reused\\n\\n  \\n\\nLaunching in 1 day, 21 hours, 24 minutes\\n\\nStarlink Group 10-27 [...] F9 B5   \\n LC-39A or SLC-40\\n\\n GTO\\n ASDS\\n\\n  \\n\\nNET Q4 2025\\n\\nStarship Flight 11\\n\\nBy SpaceX\\n\\nStarship - B15.2   \\n Starbase\\n\\n TBD\\n Ocean\\n Reused\\n\\n  \\n\\nNET Q4 2025\\n\\nUSSF-31\\n\\nBy USSF\\n\\nF9 B5   \\n LC-39A or SLC-40\\n\\n TBD\\n\\n  \\n\\nNET 2025\\n\\nNROL-77\\n\\nBy NRO\\n\\nF9 B5   \\n LC-39A or SLC-40\\n\\n TBD\\n\\n  \\n\\nNET 2025\\n\\nT1TL-A\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n OCISLY\\n\\n  \\n\\nNET Q4 2025\\n\\nSPAINSAT NG II\\n\\nBy Hisdesat\\n\\nF9 B5   \\n CCSFS, SLC-40   \\n\\nNET Oct 22, 2025, EDT\\n\\n GTO\\n Expended\\n\\n  \\n\\nLaunching in 1 month, 6 days, 3 hours [...] Starship Propellant Transfer Chaser\\n\\nBy SpaceX\\n\\nStarship   \\n Starbase\\n\\n LEO\\n\\n  \\n\\nNET 2026\\n\\nTransporter 16\\n\\nBy Multiple\\n\\nF9 B5   \\n VSFB, SLC-4E   \\n\\nNET Feb 01, 2026, EST\\n\\n SSO\\n\\n  \\n\\nLaunching in 4 months, 17 days, 23 hours\\n\\nT1TR-C\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n\\n  \\n\\nNET Q1 2026\\n\\nUSCV-12 (Crew-12)\\n\\nBy NASA\\n\\nF9 B5   \\n KSC, LC-39A\\n\\n LEO\\n LZ-2\\n\\n  \\n\\nNET Q1 2026\\n\\nT1TL-F\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n OCISLY\\n\\n  \\n\\nNET Q1 2026\\n\\nEchoStar XXV\\n\\nBy EchoStar\\n\\nTBD   \\n LC-39A or SLC-40\\n\\n GTO', 'score': 0.7882741}, {'title': 'Next Spaceflight | Rocket Launch Schedule', 'url': 'https://nextspaceflight.com/', 'content': 'Next Spaceflight | Rocket Launch Schedule\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Nusantara Lima\\n\\n ASOG \\n\\nWed Sep 10, 2025 00:01 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetailsWatch\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Tranche 1 Transport Layer B\\n\\n OCISLY \\n\\nWed Sep 10, 2025 14:12 UTC\\n\\nSLC-4E, Vandenberg SFB, California, USA', 'score': 0.7539928}, {'title': 'SpaceX Launch Schedule - RocketLaunch.org', 'url': 'https://rocketlaunch.org/launch-schedule/spacex', 'content': 'TBD\\n\\nOct 2025\\n\\n📍 Vandenberg SFB\\n\\n🚀 Falcon 9 Block 5\\n\\n🎯 Sun-Synchronous Orbit\\n\\nDedicated rideshare flight to a sun-synchronous orbit with dozens of small microsatellites and nanosatellites for commercial and government customers.\\n\\nLast Update: Changed launch site.\\n\\nSentinel-6B\\n\\nImage ...
# {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='840164c6-dd31-4658-bc78-c39c8b2c0fc4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'zwxje04dn', 'function': {'arguments': '{"query":"Next SpaceX launch"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand'}, id='run--d953bdd1-0d5f-4015-ba83-62c62d1be192', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Next SpaceX launch'}, 'id': 'zwxje04dn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 713, 'output_tokens': 30, 'total_tokens': 743}), ToolMessage(content="[{'title': 'Upcoming Missions - SpaceXNow', 'url': 'https://spacexnow.com/upcoming', 'content': '# Upcoming Missions\\n\\nClick a mission title to watch its live webcast. Titles will be underlined when a webcast is available.  \\nNote: You must log in to view webcasts on X/Twitter.\\n\\nStarlink Group 17-12\\n\\nBy SpaceX\\n\\nF9 B5 - B1088.10   \\n VSFB, SLC-4E   \\n\\n9/17/2025, 11:41:00 AM EDT\\n\\n  \\n\\nLaunching in 1 day, 3 hours, 35 minutes\\n\\nStarlink Group 10-61\\n\\nBy SpaceX\\n\\nF9 B5 - B1092.7   \\n CCSFS, SLC-40   \\n\\n9/18/2025, 5:30:00 AM EDT\\n\\n Reused\\n\\n  \\n\\nLaunching in 1 day, 21 hours, 24 minutes\\n\\nStarlink Group 10-27 [...] F9 B5   \\n LC-39A or SLC-40\\n\\n GTO\\n ASDS\\n\\n  \\n\\nNET Q4 2025\\n\\nStarship Flight 11\\n\\nBy SpaceX\\n\\nStarship - B15.2   \\n Starbase\\n\\n TBD\\n Ocean\\n Reused\\n\\n  \\n\\nNET Q4 2025\\n\\nUSSF-31\\n\\nBy USSF\\n\\nF9 B5   \\n LC-39A or SLC-40\\n\\n TBD\\n\\n  \\n\\nNET 2025\\n\\nNROL-77\\n\\nBy NRO\\n\\nF9 B5   \\n LC-39A or SLC-40\\n\\n TBD\\n\\n  \\n\\nNET 2025\\n\\nT1TL-A\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n OCISLY\\n\\n  \\n\\nNET Q4 2025\\n\\nSPAINSAT NG II\\n\\nBy Hisdesat\\n\\nF9 B5   \\n CCSFS, SLC-40   \\n\\nNET Oct 22, 2025, EDT\\n\\n GTO\\n Expended\\n\\n  \\n\\nLaunching in 1 month, 6 days, 3 hours [...] Starship Propellant Transfer Chaser\\n\\nBy SpaceX\\n\\nStarship   \\n Starbase\\n\\n LEO\\n\\n  \\n\\nNET 2026\\n\\nTransporter 16\\n\\nBy Multiple\\n\\nF9 B5   \\n VSFB, SLC-4E   \\n\\nNET Feb 01, 2026, EST\\n\\n SSO\\n\\n  \\n\\nLaunching in 4 months, 17 days, 23 hours\\n\\nT1TR-C\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n\\n  \\n\\nNET Q1 2026\\n\\nUSCV-12 (Crew-12)\\n\\nBy NASA\\n\\nF9 B5   \\n KSC, LC-39A\\n\\n LEO\\n LZ-2\\n\\n  \\n\\nNET Q1 2026\\n\\nT1TL-F\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n OCISLY\\n\\n  \\n\\nNET Q1 2026\\n\\nEchoStar XXV\\n\\nBy EchoStar\\n\\nTBD   \\n LC-39A or SLC-40\\n\\n GTO', 'score': 0.7882741}, {'title': 'Next Spaceflight | Rocket Launch Schedule', 'url': 'https://nextspaceflight.com/', 'content': 'Next Spaceflight | Rocket Launch Schedule\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Nusantara Lima\\n\\n ASOG \\n\\nWed Sep 10, 2025 00:01 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetailsWatch\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Tranche 1 Transport Layer B\\n\\n OCISLY \\n\\nWed Sep 10, 2025 14:12 UTC\\n\\nSLC-4E, Vandenberg SFB, California, USA', 'score': 0.7539928}, {'title': 'SpaceX Launch Schedule - RocketLaunch.org', 'url': 'https://rocketlaunch.org/launch-schedule/spacex', 'content': 'TBD\\n\\nOct 2025\\n\\n📍 Vandenberg SFB\\n\\n🚀 Falcon 9 Block 5\\n\\n🎯 Sun-Synchronous Orbit\\n\\nDedicated rideshare flight to a sun-synchronous orbit with dozens of small microsatellites and nanosatellites for commercial and government customers.\\n\\nLast Update: Changed launch site.\\n\\nSentinel-6B\\n\\ ...
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--a90057ff-07c3-42b9-964f-4b51cc7c4301')}, 'run_id': 'a90057ff-07c3-42b9-964f-4b51cc7c4301', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '39468545-3033-4721-9737-132d08309aff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='run--a90057ff-07c3-42b9-964f-4b51cc7c4301')}, 'run_id': 'a90057ff-07c3-42b9-964f-4b51cc7c4301', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '39468545-3033-4721-9737-132d08309aff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' next', additional_kwargs={}, response_metadata={}, id='run--a90057ff-07c3-42b9-964f-4b51cc7c4301')}, 'run_id': 'a90057ff-07c3-42b9-964f-4b51cc7c4301', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '39468545-3033-4721-9737-132d08309aff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' Space', additional_kwargs={}, response_metadata={}, id='run--a90057ff-07c3-42b9-964f-4b51cc7c4301')}, 'run_id': 'a90057ff-07c3-42b9-964f-4b51cc7c4301', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '39468545-3033-4721-9737-132d08309aff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='X', additional_kwargs={}, response_metadata={}, id='run--a90057ff-07c3-42b9-964f-4b51cc7c4301')}, 'run_id': 'a90057ff-07c3-42b9-964f-4b51cc7c4301', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '39468545-3033-4721-9737-132d08309aff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' launch', additional_kwargs={}, response_metadata={}, id='run--a90057ff-07c3-42b9-964f-4b51cc7c4301')}, 'run_id': 'a90057ff-07c3-42b9-964f-4b51cc7c4301', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '39468545-3033-4721-9737-132d08309aff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={}, id='run--a90057ff-07c3-42b9-964f-4b51cc7c4301')}, 'run_id': 'a90057ff-07c3-42b9-964f-4b51cc7c4301', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '39468545-3033-4721-9737-132d08309aff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' scheduled', additional_kwargs={}, response_metadata={}, id='run--a90057ff-07c3-42b9-964f-4b51cc7c4301')}, 'run_id': 'a90057ff-07c3-42b9-964f-4b51cc7c4301', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '39468545-3033-4721-9737-132d08309aff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={}, id='run--a90057ff-07c3-42b9-964f-4b51cc7c4301')}, 'run_id': 'a90057ff-07c3-42b9-964f-4b51cc7c4301', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '39468545-3033-4721-9737-132d08309aff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' September', additional_kwargs={}, response_metadata={}, id='run--a90057ff-07c3-42b9-964f-4b51cc7c4301')}, 'run_id': 'a90057ff-07c3-42b9-964f-4b51cc7c4301', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '39468545-3033-4721-9737-132d08309aff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--a90057ff-07c3-42b9-964f-4b51cc7c4301')}, 'run_id': 'a90057ff-07c3-42b9-964f-4b51cc7c4301', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '39468545-3033-4721-9737-132d08309aff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='17', additional_kwargs={}, response_metadata={}, id='run--a90057ff-07c3-42b9-964f-4b51cc7c4301')}, 'run_id': 'a90057ff-07c3-42b9-964f-4b51cc7c4301', 'name': 'ChatGroq', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de', 'ls_provider': 'groq', 'ls_model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'ls_model_type': 'chat', 'ls_temperature': 0.5}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d', '39468545-3033-4721-9737-132d08309aff']}
# ...
# {'event': 'on_chain_end', 'data': {'output': '__end__', 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='840164c6-dd31-4658-bc78-c39c8b2c0fc4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'zwxje04dn', 'function': {'arguments': '{"query":"Next SpaceX launch"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand'}, id='run--d953bdd1-0d5f-4015-ba83-62c62d1be192', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Next SpaceX launch'}, 'id': 'zwxje04dn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 713, 'output_tokens': 30, 'total_tokens': 743}), ToolMessage(content="[{'title': 'Upcoming Missions - SpaceXNow', 'url': 'https://spacexnow.com/upcoming', 'content': '# Upcoming Missions\\n\\nClick a mission title to watch its live webcast. Titles will be underlined when a webcast is available.  \\nNote: You must log in to view webcasts on X/Twitter.\\n\\nStarlink Group 17-12\\n\\nBy SpaceX\\n\\nF9 B5 - B1088.10   \\n VSFB, SLC-4E   \\n\\n9/17/2025, 11:41:00 AM EDT\\n\\n  \\n\\nLaunching in 1 day, 3 hours, 35 minutes\\n\\nStarlink Group 10-61\\n\\nBy SpaceX\\n\\nF9 B5 - B1092.7   \\n CCSFS, SLC-40   \\n\\n9/18/2025, 5:30:00 AM EDT\\n\\n Reused\\n\\n  \\n\\nLaunching in 1 day, 21 hours, 24 minutes\\n\\nStarlink Group 10-27 [...] F9 B5   \\n LC-39A or SLC-40\\n\\n GTO\\n ASDS\\n\\n  \\n\\nNET Q4 2025\\n\\nStarship Flight 11\\n\\nBy SpaceX\\n\\nStarship - B15.2   \\n Starbase\\n\\n TBD\\n Ocean\\n Reused\\n\\n  \\n\\nNET Q4 2025\\n\\nUSSF-31\\n\\nBy USSF\\n\\nF9 B5   \\n LC-39A or SLC-40\\n\\n TBD\\n\\n  \\n\\nNET 2025\\n\\nNROL-77\\n\\nBy NRO\\n\\nF9 B5   \\n LC-39A or SLC-40\\n\\n TBD\\n\\n  \\n\\nNET 2025\\n\\nT1TL-A\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n OCISLY\\n\\n  \\n\\nNET Q4 2025\\n\\nSPAINSAT NG II\\n\\nBy Hisdesat\\n\\nF9 B5   \\n CCSFS, SLC-40   \\n\\nNET Oct 22, 2025, EDT\\n\\n GTO\\n Expended\\n\\n  \\n\\nLaunching in 1 month, 6 days, 3 hours [...] Starship Propellant Transfer Chaser\\n\\nBy SpaceX\\n\\nStarship   \\n Starbase\\n\\n LEO\\n\\n  \\n\\nNET 2026\\n\\nTransporter 16\\n\\nBy Multiple\\n\\nF9 B5   \\n VSFB, SLC-4E   \\n\\nNET Feb 01, 2026, EST\\n\\n SSO\\n\\n  \\n\\nLaunching in 4 months, 17 days, 23 hours\\n\\nT1TR-C\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n\\n  \\n\\nNET Q1 2026\\n\\nUSCV-12 (Crew-12)\\n\\nBy NASA\\n\\nF9 B5   \\n KSC, LC-39A\\n\\n LEO\\n LZ-2\\n\\n  \\n\\nNET Q1 2026\\n\\nT1TL-F\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n OCISLY\\n\\n  \\n\\nNET Q1 2026\\n\\nEchoStar XXV\\n\\nBy EchoStar\\n\\nTBD   \\n LC-39A or SLC-40\\n\\n GTO', 'score': 0.7882741}, {'title': 'Next Spaceflight | Rocket Launch Schedule', 'url': 'https://nextspaceflight.com/', 'content': 'Next Spaceflight | Rocket Launch Schedule\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Nusantara Lima\\n\\n ASOG \\n\\nWed Sep 10, 2025 00:01 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetailsWatch\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Tranche 1 Transport Layer B\\n\\n OCISLY \\n\\nWed Sep 10, 2025 14:12 UTC\\n\\nSLC-4E, Vandenberg SFB, California, USA', 'score': 0.7539928}, {'title': 'SpaceX Launch Schedule - RocketLaunch.org', 'url': 'https://rocketlaunch.org/launch-schedule/spacex', 'content': 'TBD\\n\\nOct 2025\\n\\n📍 Vandenberg SFB\\n\\n🚀 Falcon 9 Block 5\\n\\n🎯 Sun-Synchronous Orbit\\n\\nDedicated rideshare flight to a sun-synchronous orbit with dozens of small microsatellites and nanosatellites for commercial and government customers.\\n\\nLast Update: Changed launch site.\\n\\nSen ...
# {'event': 'on_chain_stream', 'run_id': '39468545-3033-4721-9737-132d08309aff', 'name': 'model', 'tags': ['graph:step:3'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:f517d451-15d4-3e48-f78d-0b9be37153de'}, 'data': {'chunk': {'messages': [AIMessage(content='The next SpaceX launch is scheduled for September 17, 2025, at 11:41:00 AM EDT, which is the Starlink Group 17-12 mission. The launch will take place at VSFB, SLC-4E. \n\nYou can find more information about upcoming SpaceX launches on websites such as SpaceXNow, Next Spaceflight, and RocketLaunch.org.', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand'}, id='run--a90057ff-07c3-42b9-964f-4b51cc7c4301', usage_metadata={'input_tokens': 2417, 'output_tokens': 81, 'total_tokens': 2498})]}}, 'parent_ids': ['97148894-65ec-438e-ac64-9fd6b01bca5d']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content='The next SpaceX launch is scheduled for September 17, 2025, at 11:41:00 AM EDT, which is the Starlink Group 17-12 mission. The launch will take place at VSFB, SLC-4E. \n\nYou can find more information about upcoming SpaceX launches on websites such as SpaceXNow, Next Spaceflight, and RocketLaunch.org.', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand'}, id='run--a90057ff-07c3-42b9-964f-4b51cc7c4301', usage_metadata={'input_tokens': 2417, 'output_tokens': 81, 'total_tokens': 2498})]}, 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='840164c6-dd31-4658-bc78-c39c8b2c0fc4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'zwxje04dn', 'function': {'arguments': '{"query":"Next SpaceX launch"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand'}, id='run--d953bdd1-0d5f-4015-ba83-62c62d1be192', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Next SpaceX launch'}, 'id': 'zwxje04dn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 713, 'output_tokens': 30, 'total_tokens': 743}), ToolMessage(content="[{'title': 'Upcoming Missions - SpaceXNow', 'url': 'https://spacexnow.com/upcoming', 'content': '# Upcoming Missions\\n\\nClick a mission title to watch its live webcast. Titles will be underlined when a webcast is available.  \\nNote: You must log in to view webcasts on X/Twitter.\\n\\nStarlink Group 17-12\\n\\nBy SpaceX\\n\\nF9 B5 - B1088.10   \\n VSFB, SLC-4E   \\n\\n9/17/2025, 11:41:00 AM EDT\\n\\n  \\n\\nLaunching in 1 day, 3 hours, 35 minutes\\n\\nStarlink Group 10-61\\n\\nBy SpaceX\\n\\nF9 B5 - B1092.7   \\n CCSFS, SLC-40   \\n\\n9/18/2025, 5:30:00 AM EDT\\n\\n Reused\\n\\n  \\n\\nLaunching in 1 day, 21 hours, 24 minutes\\n\\nStarlink Group 10-27 [...] F9 B5   \\n LC-39A or SLC-40\\n\\n GTO\\n ASDS\\n\\n  \\n\\nNET Q4 2025\\n\\nStarship Flight 11\\n\\nBy SpaceX\\n\\nStarship - B15.2   \\n Starbase\\n\\n TBD\\n Ocean\\n Reused\\n\\n  \\n\\nNET Q4 2025\\n\\nUSSF-31\\n\\nBy USSF\\n\\nF9 B5   \\n LC-39A or SLC-40\\n\\n TBD\\n\\n  \\n\\nNET 2025\\n\\nNROL-77\\n\\nBy NRO\\n\\nF9 B5   \\n LC-39A or SLC-40\\n\\n TBD\\n\\n  \\n\\nNET 2025\\n\\nT1TL-A\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n OCISLY\\n\\n  \\n\\nNET Q4 2025\\n\\nSPAINSAT NG II\\n\\nBy Hisdesat\\n\\nF9 B5   \\n CCSFS, SLC-40   \\n\\nNET Oct 22, 2025, EDT\\n\\n GTO\\n Expended\\n\\n  \\n\\nLaunching in 1 month, 6 days, 3 hours [...] Starship Propellant Transfer Chaser\\n\\nBy SpaceX\\n\\nStarship   \\n Starbase\\n\\n LEO\\n\\n  \\n\\nNET 2026\\n\\nTransporter 16\\n\\nBy Multiple\\n\\nF9 B5   \\n VSFB, SLC-4E   \\n\\nNET Feb 01, 2026, EST\\n\\n SSO\\n\\n  \\n\\nLaunching in 4 months, 17 days, 23 hours\\n\\nT1TR-C\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n\\n  \\n\\nNET Q1 2026\\n\\nUSCV-12 (Crew-12)\\n\\nBy NASA\\n\\nF9 B5   \\n KSC, LC-39A\\n\\n LEO\\n LZ-2\\n\\n  \\n\\nNET Q1 2026\\n\\nT1TL-F\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n OCISLY\\n\\n  \\n\\nNET Q1 2026\\n\\nEchoStar XXV\\n\\nBy EchoStar\\n\\nTBD   \\n LC-39A or SLC-40\\n\\n GTO', 'score': 0.7882741}, {'title': 'Next Spaceflight | Rocket Launch Schedule', 'url': 'https://nextspaceflight.com/', 'content': 'Next Spaceflight | Rocket Launch Schedule\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Nusantara Lima\\n\\n ASOG \\n\\nWed Sep 10, 2025 00:01 UTC\\n\\nSLC-40, Cape  ...
# {'event': 'on_chain_stream', 'run_id': '97148894-65ec-438e-ac64-9fd6b01bca5d', 'name': 'LangGraph', 'tags': [], 'metadata': {'thread_id': 8}, 'data': {'chunk': {'model': {'messages': [AIMessage(content='The next SpaceX launch is scheduled for September 17, 2025, at 11:41:00 AM EDT, which is the Starlink Group 17-12 mission. The launch will take place at VSFB, SLC-4E. \n\nYou can find more information about upcoming SpaceX launches on websites such as SpaceXNow, Next Spaceflight, and RocketLaunch.org.', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand'}, id='run--a90057ff-07c3-42b9-964f-4b51cc7c4301', usage_metadata={'input_tokens': 2417, 'output_tokens': 81, 'total_tokens': 2498})]}}}, 'parent_ids': []}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='840164c6-dd31-4658-bc78-c39c8b2c0fc4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'zwxje04dn', 'function': {'arguments': '{"query":"Next SpaceX launch"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand'}, id='run--d953bdd1-0d5f-4015-ba83-62c62d1be192', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Next SpaceX launch'}, 'id': 'zwxje04dn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 713, 'output_tokens': 30, 'total_tokens': 743}), ToolMessage(content="[{'title': 'Upcoming Missions - SpaceXNow', 'url': 'https://spacexnow.com/upcoming', 'content': '# Upcoming Missions\\n\\nClick a mission title to watch its live webcast. Titles will be underlined when a webcast is available.  \\nNote: You must log in to view webcasts on X/Twitter.\\n\\nStarlink Group 17-12\\n\\nBy SpaceX\\n\\nF9 B5 - B1088.10   \\n VSFB, SLC-4E   \\n\\n9/17/2025, 11:41:00 AM EDT\\n\\n  \\n\\nLaunching in 1 day, 3 hours, 35 minutes\\n\\nStarlink Group 10-61\\n\\nBy SpaceX\\n\\nF9 B5 - B1092.7   \\n CCSFS, SLC-40   \\n\\n9/18/2025, 5:30:00 AM EDT\\n\\n Reused\\n\\n  \\n\\nLaunching in 1 day, 21 hours, 24 minutes\\n\\nStarlink Group 10-27 [...] F9 B5   \\n LC-39A or SLC-40\\n\\n GTO\\n ASDS\\n\\n  \\n\\nNET Q4 2025\\n\\nStarship Flight 11\\n\\nBy SpaceX\\n\\nStarship - B15.2   \\n Starbase\\n\\n TBD\\n Ocean\\n Reused\\n\\n  \\n\\nNET Q4 2025\\n\\nUSSF-31\\n\\nBy USSF\\n\\nF9 B5   \\n LC-39A or SLC-40\\n\\n TBD\\n\\n  \\n\\nNET 2025\\n\\nNROL-77\\n\\nBy NRO\\n\\nF9 B5   \\n LC-39A or SLC-40\\n\\n TBD\\n\\n  \\n\\nNET 2025\\n\\nT1TL-A\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n OCISLY\\n\\n  \\n\\nNET Q4 2025\\n\\nSPAINSAT NG II\\n\\nBy Hisdesat\\n\\nF9 B5   \\n CCSFS, SLC-40   \\n\\nNET Oct 22, 2025, EDT\\n\\n GTO\\n Expended\\n\\n  \\n\\nLaunching in 1 month, 6 days, 3 hours [...] Starship Propellant Transfer Chaser\\n\\nBy SpaceX\\n\\nStarship   \\n Starbase\\n\\n LEO\\n\\n  \\n\\nNET 2026\\n\\nTransporter 16\\n\\nBy Multiple\\n\\nF9 B5   \\n VSFB, SLC-4E   \\n\\nNET Feb 01, 2026, EST\\n\\n SSO\\n\\n  \\n\\nLaunching in 4 months, 17 days, 23 hours\\n\\nT1TR-C\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n\\n  \\n\\nNET Q1 2026\\n\\nUSCV-12 (Crew-12)\\n\\nBy NASA\\n\\nF9 B5   \\n KSC, LC-39A\\n\\n LEO\\n LZ-2\\n\\n  \\n\\nNET Q1 2026\\n\\nT1TL-F\\n\\nBy SDA\\n\\nF9 B5   \\n VSFB, SLC-4E\\n\\n Polar\\n OCISLY\\n\\n  \\n\\nNET Q1 2026\\n\\nEchoStar XXV\\n\\nBy EchoStar\\n\\nTBD   \\n LC-39A or SLC-40\\n\\n GTO', 'score': 0.7882741}, {'title': 'Next Spaceflight | Rocket Launch Schedule', 'url': 'https://nextspaceflight.com/', 'content': 'Next Spaceflight | Rocket Launch Schedule\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Nusantara Lima\\n\\n ASOG \\n\\nWed Sep 10, 2025 00:01 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetailsWatch\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Tranche 1 Transport Layer B\\n\\n OCISLY \\n\\nWed Sep 10, 2025 14:12 UTC\\n\\nSLC-4E, Vandenberg SFB, California, USA', 'score': 0.7539928}, {'title': 'SpaceX Launch Schedule - RocketLaunch.org', 'url': 'https://rocketlaunch.org/launch-schedule/spacex', 'content': 'TBD\\n\\nOct 2025\\n\\n📍 Vandenberg SFB\\n\\n🚀 Falcon 9 Block 5\\n\\n🎯 Sun-Synchronous Orbit\\n\\nDedicated rideshare flight to a sun-synchronous orbit with dozens of small microsatellites and nanosatellites for commercial and government customers.\\n\\nLast Update: Changed launch site.\\n\\nSentinel-6B\\n\\nImage  ...
